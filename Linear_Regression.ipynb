# %% [markdown]
# Linear Regression Practical Impementation

# %%
from sklearn.datasets import fetch_california_housing

# %%
dataset=fetch_california_housing()

# %%
dataset
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
print(dataset)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
import pandas as pd

# %%
print(dataset.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
pd.DataFrame(dataset.data,columns=dataset.feature_names)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df=pd.DataFrame(dataset.data,columns=dataset.feature_names)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df['Price']=dataset.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         Price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# Price         0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
df_copy=df.sample(frac=0.25)

# %%
df_copy.shape
# Out:
# (5160, 9)

# %%
sns.pairplot(df_copy)

# %% [markdown]
#  Divide  the dataset into independent and dependent

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %% [markdown]
# Divide the dataset into train & test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.33, random_state=36)

# %%
X_train.shape # X_train is all independent feature
# Out:
# (13828, 8)

# %% [markdown]
# X_test.shape #  X_train output is  y_train

# %% [markdown]
# feature scaling - Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
# scaler.fit()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test= scaler.transform(X_test)

# %%
X_test = scaler.transform(X_test)
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([ 0.83700024,  0.12271899, -0.26347102,  0.30713139, -0.0081633 ,
#        -0.02764702, -0.90609856, -0.87576409])

# %%
regression.intercept_
# Out:
# 2.0708259184263804

# %%
#prediction

# %%
y_pred=regression.predict(X_test)

# %%
y_pred
# Out:
# array([-37.19086304, -37.68906821, -36.87766407, ..., -35.45117033,
#        -35.91988583, -37.33770191])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error (MAE):", mae)

rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Squared Error (MSE): 1528.9100233620172
# Mean Absolute Error (MAE): 39.089259384594634
# Root Mean Squared Error (RMSE): 39.101279050205214

# %%
import numpy as np
mse=mean_squared_error(y_test,y_pred)
print(mse)
mae=mean_absolute_error(y_test,y_pred)
print(mae)
print(np.sqrt(mse))
# Out:
# 1528.9100233620172
# 39.089259384594634
# 39.101279050205214

# %%
# Accuracy r2 and adjusted r square

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# -1181.027454253712

# %%
score =r2_score(y_test,y_pred)

# %%
#display adjusted R-squared
1 - (1-score)*(len(y)-1)/(len(y)-X.shape[1]-1)
# Out:
# -1181.4858042917144

# %%
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=20)
ridge.fit(X_train,y_train)
# Out:
# Ridge(alpha=20)

# %%
y_pred=ridge.predict(X_test)

# %%
y_pred
# Out:
# array([-36.39930867, -36.89635947, -36.0909305 , ..., -34.66320174,
#        -35.13296565, -36.54623962])

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
mae=mean_absolute_error(y_test,y_pred)
print(mae)
print(np.sqrt(mse))
# Out:
# 1467.9149653057082
# 38.30117815418272
# 38.313378411538025

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=20)
lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=20)

# %%
y_pred=lasso.predict(X_test)

# %%
y_pred
# Out:
# array([2.07082592, 2.07082592, 2.07082592, ..., 2.07082592, 2.07082592,
#        2.07082592])

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
mae=mean_absolute_error(y_test,y_pred)
print(mae)
print(np.sqrt(mse))
# Out:
# 1.2935112672240048
# 0.9000629779192262
# 1.1373263679454568

# %%
from sklearn.linear_model import ElasticNet
elasticnet=ElasticNet(alpha=20)
elasticnet.fit(X_train,y_train)
# Out:
# ElasticNet(alpha=20)

# %%
y_pred=elasticnet.predict(X_test)

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
mae=mean_absolute_error(y_test,y_pred)
print(mae)
print(np.sqrt(mse))
# Out:
# 1.2935112672240048
# 0.9000629779192262
# 1.1373263679454568

# %%
df_copy.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.103840  0.395567  -0.063857    0.016363  0.002043
# HouseAge   -0.103840  1.000000 -0.180838  -0.112272   -0.303467  0.015798
# AveRooms    0.395567 -0.180838  1.000000   0.787667   -0.079085  0.008009
# AveBedrms  -0.063857 -0.112272  0.787667   1.000000   -0.079093 -0.003186
# Population  0.016363 -0.303467 -0.079085  -0.079093    1.000000  0.101594
# AveOccup    0.002043  0.015798  0.008009  -0.003186    0.101594  1.000000
# Latitude   -0.084203  0.002700  0.112076   0.077513   -0.098981 -0.021898
# Longitude  -0.010431 -0.097698 -0.024115   0.019509    0.089734  0.034762
# Price       0.668669  0.119684  0.161675  -0.059646   -0.014932 -0.060651
#
#             Latitude  Longitude     Price
# MedInc     -0.084203  -0.010431  0.668669
# HouseAge    0.002700  -0.097698  0.119684
# AveRooms    0.112076  -0.024115  0.161675
# AveBedrms   0.077513   0.019509 -0.059646
# ...

# %% [markdown]
# When the data is correlated with the target variable (dependent variable), it means that there is a relationship or association between the independent variables (features) and the target variable
